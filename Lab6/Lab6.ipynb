# %% [markdown]
# # Wyszukiwarka

# %% [markdown]
# #### Plan:
# tremin: 20.12.2017
# 1. Dictionary
#     - Stop words removed
#     - Stemming (Porter Stemmer, Porter Stemmer 2)
#     - Reduction (optional)
# 2. Budowa BackOfWords (indeksowanie)
#     - documentTermMatrix (wektory słów dla każdego artykułu)
#     - Inverse Document Frequency (IDF(w) - przemnożenie kolumny słowa w w documentTermMatrix przez IDF(w)
#     - Normalizacja (sprowadzenie wektora dla każdego dokumentu do jednostkowego - przydatne przy danych o zróżnicowanej długości)
# 3. Query
#     - Przekleństwo wymiaru
#     - iloczyn skalarny
# 4. SVD (LRMA)
#     - biblioteka, która liczy pierwsze k wektorów
#     - biblioteka dla danych żadkich
# 5. * Semantyka w nietrywialny sposób
#     - Latent semantic indexing
#     - Latent Dirichlet approximation

# %%
import pandas as pd
from tqdm import tqdm
import re
import numpy as np
from nltk.stem import PorterStemmer, snowball
from nltk.stem import WordNetLemmatizer
from scipy.sparse import csr_matrix, lil_matrix
import itertools
from math import log

# %% [markdown]
# ### Params

# %%
filename = "data.tsv"
column_name = 'review'
# filename = "articles2.csv"
# column_name = 'Article'
# filename = 'buzzfeed.csv'
# column_name = ?
stopwords_filename = "stopwords"

# %%
texts = pd.read_csv(filename, header=0, delimiter="\t")
# texts = pd.read_csv(filename)

# %%
texts.shape
# Out:
# (44064, 5)

# %%
texts['title'][31]
# Out:
# 'Street Food In Bangkok That Will Make You Eat To The Top'

# %%
texts['first_paragraph'][3]
# Out:
# 'Carol Pilon is one of a handful people on Earth who risk their lives by performing on the wings of airplanes flying 150 miles an hour hundreds of feet above the ground. And she’s trying to mentor a new generation to carry on the dying — and deadly — art form.'

# %%
texts['text'][3]
# Out:
# 'before I could see it, the engine growling loudly. And then the scarlet biplane came into view, a dark figure suspended between the parallel wings becoming more distinct as it flew toward the Lake Erie shoreline where thousands of spectators were waiting for the next air show act. That figure was Carol Pilon, one of the world’s last remaining wingwalkers, and she appeared to be floating, the finger-width flying wires supporting her invisible to the audience from that distance. Her longtime pilot, Marcus Paine, accelerated into a loop, drawing a large cursive O in the sky with smoke; only centrifugal force and Pilon’s own strength kept her from falling as the plane flew upside down and then righted itself barely a hundred feet above the waterfront showbox. Then the 1940 Boeing Stearman turned away from the shore, providing the audience with a silhouette of the biplane, Pilon suspended like a spider over her carefully spun web. Paine gained altitude and turned back toward the crowd before pulling back the throttle, stopping the propeller blades and the 150 mile-per-hour blast that could blow Pilon off the wing. The 2,000-pound Stearman glided gracefully as a seabird while Pilon moved off the wires and wove herself between the struts toward the cockpit, balancing on the narrow wooden spar that makes up the spine of the wing and the only beam strong enough to hold her weight. This was the moment when the audience realized that she, truly, was walking on the wing, hundreds of feet in the air. If the pilot didn\'t fly level, if a bird were to hit her, there would be little she could do, no matter her years of experience and thousands of hours of training. Pilon climbed up, past the cockpit and onto the top wing where a slender pole was affixed. From the shore the audience could barely make out the moment she strapped her safety belt onto the brace with a heavy carabineer. She gave a wave to the crowd and signaled to Paine. The plane had been losing altitude while she transitioned, and the engine started up again with a roar. The next sequence with Pilon “on the top rack,” as she calls it, involved Paine directing the Stearman through a series of aerobatic maneuvers: a loop, barrel roll, figure eight. Pilon’s job is to project beauty and grace from the wing and also to not die spectacularly. She waved to the audience as the pair flew low and then she transitioned to more intricate balances: the Mercury Man with arms outstretched and one foot raised, and the Human Flag, where she hangs her body off the brace. And then Paine flew off, Pilon’s dark figure contrasted against the white of the clouds, the pale blue of the sky, a woman on top of the world. \n    \n\n    \n       \n    \n   Later Pilon would tell me that every moment of her act is designed to maximize the audience’s experience. The backlit airplane, Pilon’s Lady of Victory pose — all deliberate scenes meant to come together in an expertly choreographed act. And that is the beauty of wingwalking: an art form almost as old as flight itself. Yet in the tiny world of the air show industry, where this nostalgic spectacle must compete with increasingly powerful jet engines, pyrotechnics, giant military bombers, and whatever is on your phone at any given moment, it is easy to understand why Pilon is one of the last wingwalkers in the world, and perhaps the only one actively mentoring young women who have felt the same draw. The only way to truly experience this is to see one of the 10 to 20 times a season when Pilon will take off while balanced on the wing of her plane, for crowds that might range from a few thousand to, occasionally, more than a million. Her performance fee barely breaks even with her costs for airplane maintenance, fuel, and more. I had come to this Dunkirk-Lake Shore air show as the third generation of my family to learn to fly. This would be the first air show hosted by my family’s airport in decades, and I wanted to see how the industry had evolved since I mo ...

# %%
bag_of_words = set()
with open(stopwords_filename, "r") as file:
    stopwords = set(file.read().splitlines()[1:])

# %%
# ps = PorterStemmer()
ps = snowball.EnglishStemmer()
wnl = WordNetLemmatizer()

# %%
for i, row in tqdm(texts.iterrows()):
#     row[column_name] = list(map(lambda x : ps.stem(re.sub('[^a-z]', '', x.lower())), row[column_name].split()))
    row[column_name] = list(map(lambda x : ps.stem(re.sub('[^a-z]', '', wnl.lemmatize(x))),
                                filter(lambda word : word not in stopwords, row[column_name].lower().split())))
    for word in row[column_name]:
        bag_of_words.add(word)
# Out:
# 25000it [01:29, 279.04it/s]

# %%
len(bag_of_words)
# Out:
# 87329

# %%
frequency = {word: 0 for word in bag_of_words}
for i, row in tqdm(texts.iterrows()):
    for word in row[column_name]:
        if word in bag_of_words:
            frequency[word] += 1
# Out:
# 25000it [00:03, 6410.94it/s]

# %%
frequency = dict(filter(lambda x : len(x[0]) > 1, sorted(frequency.items(), key=lambda x: x[1], reverse=True)))

# %%
frequency
# Out:
# {'br': 57204,
#  'movi': 49381,
#  'film': 45774,
#  'time': 14718,
#  'good': 14230,
#  'charact': 13795,
#  'watch': 13650,
#  'it': 12803,
#  'the': 12511,
#  'stori': 11620,
#  'scene': 10472,
#  'show': 9780,
#  'bad': 9413,
#  'great': 9221,
#  'love': 8969,
#  'peopl': 8827,
#  'play': 8460,
#  'act': 8375,
#  'life': 6704,
#  'plot': 6484,
#  'actor': 6456,
#  'work': 6420,
#  'year': 5927,
#  'man': 5484,
#  'this': 5455,
#  'find': 5302,
#  'perform': 5066,
#  'part': 5026,
#  'feel': 4939,
#  'lot': 4884,
#  'guy': 4742,
#  'interest': 4662,
#  'director': 4500,
#  'real': 4497,
#  'funni': 4253,
#  'music': 4186,
#  'give': 4106,
#  'enjoy': 4049,
#  'cast': 4045,
#  'end': 3978,
#  'start': 3929,
#  'role': 3918,
#  'woman': 3692,
#  'thought': 3672,
#  'girl': 3671,
#  'set': 3669,
#  'point': 3665,
#  'turn': 3658,
#  'star': 3638,
#  'kill': 3623,
#  'well': 3611,
#  'world': 3567,
#  'minut': 3562,
#  'fact': 3557,
#  'pretti': 3556,
#  'day': 3549,
#  'effect': 3517,
#  'origin': 3515,
#  'comedi': 3482,
#  'horror': 3476,
#  'direct': 3468,
#  'and': 3397,
#  'friend': 3379,
#  'young': 3349,
#  'big': 3349,
#  'one': 3292,
#  'all': 3274,
#  'fan': 3265,
#  'long': 3247,
#  'action': 3223,
#  'person': 3190,
#  'bit': 3188,
#  'line': 3173,
#  'live': 3113,
#  'that': 3092,
#  'put': 3089,
#  'beauti': 3077,
#  'script': 3064,
#  'complet': 3064,
#  'laugh': 3056,
#  'final': 3048,
#  'high': 3028,
#  'kid': 3024,
#  'kind': 2944,
#  'seri': 2903,
#  'reason': 2891,
#  'shot': 2881,
#  'expect': 2878,
#  'call': 2836,
#  'famili': 2812,
#  'tv': 2740,
#  'place': 2658,
#  'book': 2652,
#  'entertain': 2627,
#  'lead': 2611,
#  'is': 2605,
#  'fun': 2590,
#  'howev': 2589,
#  'moment': 2587,
#  'make': 2585,
#  'happen': 2579,
#  'in': 2573,
#  'worst': 2560,
#  'screen': 2550,
#  'poor': 2544,
#  'me': 2543,
#  'read': 2522,
#  'idea': 2517,
#  'way': 2506,
#  'run': 2489,
#  'dvd': 2489,
#  'war': 2487,
#  'american': 2484,
#  'audienc': 2483,
#  'wonder': 2482,
#  'there': 2461,
#  'bore': 2436,
#  'main': 2391,
#  'worth': 2380,
#  'surpris': 2376,
#  'sound': 2366,
#  'hard': 2363,
#  'recommend': 2355,
#  'move': 2323,
#  'episod': 2304,
#  'hope': 2294,
#  'perfect': 2291,
#  'job': 2278,
#  'sens': 2234,
#  'take': 2224,
#  'them': 2209,
#  'short': 2207,
#  'special': 2201,
#  'him': 2194,
#  'problem': 2179,
#  'boy': 2172,
#  'product': 2171,
#  'excel': 2139,
#  'open': 2133,
#  'understand': 2133,
#  'begin': 2132,
#  'wast': 2126,
#  'human': 2121,
#  'true': 2118,
#  'suppos': 2115,
#  'black': 2114,
#  'night': 2113,
#  'view': 2103,
#  'nice': 2093,
#  'death': 2092,
#  'here': 2074,
#  'version': 2071,
#  'money': 2071,
#  'total': 2070,
#  'face': 2070,
#  'review': 2067,
#  'talk': 2057,
#  'classic': 2055,
#  'mind': 2038,
#  'you': 2031,
#  'care': 2012,
#  'think': 2010,
#  'left': 2003,
#  'john': 1990,
#  'hour': 1983,
#  'stupid': 1967,
#  'out': 1946,
#  'child': 1946,
#  'rememb': 1941,
#  'involv': 1939,
#  'but': 1938,
#  'head': 1930,
#  'write': 1929,
#  'rate': 1928,
#  'again': 1922,
#  'murder': 1905,
#  'coupl': 1904,
#  'on': 1901,
#  'piec': 1899,
#  'includ': 1894,
#  'wife': 1885,
#  'appear': 1884,
#  'simpli': 1883,
#  'dead': 1882,
#  'terribl': 1881,
#  'attempt': 1876,
#  'fall': 1865,
#  'releas': 1855,
#  'hous': 1854,
#  'want': 1845,
#  'viewer': 1842,
#  'fight': 1839,
#  'absolut': 1838,
#  'word': 1831,
#  'hand': 1831,
#  'men': 1830,
#  'eye': 1817,
#  'lack': 1815,
#  'school': 1811,
#  'home': 1807,
#  'portray': 1803,
#  'power': 1792,
#  'featur': 1790,
#  'pictur': 1781,
#  'produc': 1756,
#  'decid': 1753,
#  'disappoint': 1752,
#  'so': 1751,
#  'wrong': 1750,
#  'emot': 1746,
#  'father': 1745,
#  'song': 1743,
#  'game': 1740,
#  'camera': 1737,
#  'die': 1734,
#  'talent': 1731,
#  'titl': 1727,
#  'video': 1717,
#  'anim': 1712,
#  'hollywood': 1708,
#  'mean': 1704,
#  'save': 1695,
#  'rest': 1695,
#  'budget': 1686,
#  'aw': 1665,
#  'top': 1657,
#  'full': 1648,
#  'humor': 1644,
#  'sex': 1642,
#  'look': 1641,
#  'sort': 1629,
#  'mother': 1628,
#  'comment': 1615,
#  'amaz': 1607,
#  'dark': 1602,
#  'dialogu': 1597,
#  'bring': 1593,
#  'as': 1585,
#  'chang': 1580,
#  'guess': 1575,
#  'creat': 1567,
#  'joke': 1564,
#  'case': 1563,
#  'base': 1562,
#  'flick': 1557,
#  'name': 1556,
#  'like': 1547,
#  'see': 1531,
#  'meet': 1528,
#  'experi': 1528,
#  'sad': 1527,
#  'horribl': 1522,
#  'not': 1522,
#  'forc': 1520,
#  'up': 1519,
#  'leav': 1517,
#  'style': 1510,
#  'sequenc': 1502,
#  'earli': 1482,
#  'mention': 1476,
#  'car': 1474,
#  'matter': 1467,
#  'small': 1465,
#  'manag': 1454,
#  'extrem': 1453,
#  'thing': 1451,
#  'close': 1449,
#  'qualiti': 1444,
#  'tell': 1441,
#  'her': 1440,
#  'entir': 1436,
#  'stop': 1435,
#  'too': 1433,
#  'now': 1421,
#  'drama': 1420,
#  'side': 1407,
#  'wors': 1404,
#  'light': 1399,
#  'other': 1399,
#  'art': 1396,
#  'cinema': 1389,
#  'brilliant': 1384,
#  'if': 1379,
#  'imagin': 1377,
#  'cut': 1377,
#  'written': 1372,
#  'impress': 1364,
#  'basic': 1362,
#  'lost': 1357,
#  'actress': 1350,
#  'brother': 1349,
#  'develop': 1349,
#  'fail': 1346,
#  'group': 1342,
#  'favorit': 1340,
#  'felt': 1338,
#  'learn': 1334,
#  'present': 1334,
#  'deal': 1328,
#  'writer': 1328,
#  'what': 1324,
#  'wait': 1311,
#  'hit': 1307,
#  'son': 1300,
#  'killer': 1300,
#  'come': 1299,
#  'age': 1297,
#  'type': 1293,
#  'believ': 1292,
#  'relationship': 1288,
#  'know': 1287,
#  'robert': 1285,
#  'heart': 1285,
#  'rent': 1277,
#  'hero': 1276,
#  'seen': 1274,
#  'hate': 1270,
#  'question': 1267,
#  'walk': 1265,
#  'natur': 1260,
#  'miss': 1257,
#  'score': 1254,
#  'voic': 1251,
#  'white': 1246,
#  'sit': 1246,
#  'support': 1241,
#  'twist': 1238,
#  'filmmak': 1238,
#  'stand': 1237,
#  'credit': 1235,
#  'today': 1234,
#  'evil': 1234,
#  'hilari': 1225,
#  'michael': 1223,
#  'say': 1222,
#  'deserv': 1221,
#  'fine': 1221,
#  'add': 1219,
#  'import': 1219,
#  'be': 1217,
#  'monster': 1211,
#  'strong': 1208,
#  'success': 1206,
#  'histori': 1204,
#  'town': 1203,
#  'danc': 1199,
#  'stay': 1192,
#  'daughter': 1192,
#  'situat': 1190,
#  'citi': 1189,
#  'number': 1188,
#  'stuff': 1186,
#  'gave': 1185,
#  'god': 1176,
#  'major': 1175,
#  'though': 1175,
#  'possibl': 1172,
#  'genr': 1169,
#  'order': 1166,
#  'appar': 1155,
#  'edit': 1151,
#  'late': 1148,
#  'theme': 1146,
#  'do': 1145,
#  'realiz': 1140,
#  'touch': 1138,
#  'general': 1136,
#  'incred': 1134,
#  'annoy': 1133,
#  'bodi': 1132,
#  'mysteri': 1132,
#  'to': 1131,
#  'return': 1129,
#  'mr': 1125,
#  'with': 1117,
#  'obvious': 1116,
#  'chanc': 1115,
#  'event': 1114,
#  'decent': 1109,
#  'ridicul': 1106,
#  'for': 1099,
#  'continu': 1096,
#  'heard': 1096,
#  'help': 1091,
#  'cours': 1089,
#  'level': 1086,
#  'speak': 1085,
#  'yes': 1082,
#  'cool': 1076,
#  'pick': 1068,
#  'right': 1066,
#  'critic': 1063,
#  'countri': 1061,
#  'told': 1056,
#  'suspens': 1056,
#  'figur': 1053,
#  'strang': 1041,
#  'dog': 1040,
#  'compar': 1040,
#  'david': 1035,
#  'documentari': 1034,
#  'huge': 1034,
#  'shoot': 1032,
#  'actual': 1031,
#  'hold': 1030,
#  'shown': 1022,
#  'subject': 1022,
#  'polic': 1021,
#  'visual': 1018,
#  'no': 1018,
#  'state': 1016,
#  'realiti': 1015,
#  'deliv': 1014,
#  'element': 1014,
#  'simpl': 1012,
#  'itbr': 1012,
#  'pace': 1011,
#  'hell': 1008,
#  'sister': 1008,
#  'similar': 1008,
#  'predict': 1008,
#  'also': 1007,
#  'effort': 1005,
#  'comic': 1005,
#  'career': 1005,
#  'offer': 1004,
#  'blood': 1000,
#  'dialog': 998,
#  'local': 997,
#  'cop': 996,
#  'opinion': 995,
#  'convinc': 994,
#  'slow': 992,
#  'pain': 989,
#  'femal': 987,
#  'silli': 987,
#  'shock': 986,
#  'was': 983,
#  'explain': 980,
#  'violenc': 980,
#  'result': 979,
#  'train': 978,
#  'team': 977,
#  'happi': 973,
#  'husband': 973,
#  'buy': 970,
#  'english': 970,
#  'better': 966,
#  'jame': 966,
#  'sequel': 963,
#  'crap': 963,
#  'confus': 962,
#  'check': 953,
#  'drug': 949,
#  'quick': 947,
#  'hear': 947,
#  'theater': 947,
#  'alien': 940,
#  'western': 939,
#  'pull': 936,
#  'room': 935,
#  'anyway': 934,
#  'note': 934,
#  'parent': 934,
#  'cover': 934,
#  'more': 930,
#  'cinematographi': 929,
#  'usual': 929,
#  'sure': 928,
#  'break': 928,
#  'escap': 928,
#  'knew': 927,
#  'which': 926,
#  'honest': 926,
#  'then': 924,
#  'off': 921,
#  'etc': 918,
#  'gore': 916,
#  'imag': 915,
#  'offic': 915,
#  'clear': 914,
#  'space': 910,
#  'avoid': 907,
#  'made': 906,
#  'first': 905,
#  'focus': 903,
#  'jack': 902,
#  'remain': 901,
#  'unfortun': 901,
#  'detail': 900,
#  'carri': 899,
#  'build': 898,
#  'polit': 898,
#  'who': 895,
#  'soundtrack': 893,
#  'cheap': 891,
#  'doctor': 885,
#  'attent': 885,
#  'of': 884,
#  'french': 884,
#  'televis': 879,
#  'member': 879,
#  'teenag': 876,
#  'relat': 875,
#  'typic': 875,
#  'fit': 874,
#  'messag': 874,
#  'remind': 871,
#  'due': 871,
#  'pay': 868,
#  'tale': 868,
#  'sexual': 867,
#  'doubt': 865,
#  'thriller': 865,
#  'ladi': 864,
#  'dream': 864,
#  'differ': 862,
#  'form': 862,
#  'discov': 861,
#  'copi': 857,
#  'excit': 854,
#  'modern': 852,
#  'moviebr': 852,
#  'singl': 850,
#  'clich': 849,
#  'notic': 848,
#  'previous': 846,
#  'ten': 845,
#  'locat': 836,
#  'master': 834,
#  'captur': 832,
#  'spend': 831,
#  'ad': 830,
#  'fill': 830,
#  'respect': 829,
#  'plan': 829,
#  'william': 828,
#  'soldier': 828,
#  'gun': 827,
#  'follow': 825,
#  'much': 824,
#  'rock': 824,
#  'air': 824,
#  'villain': 822,
#  'or': 821,
#  'georg': 817,
#  'dr': 814,
#  'forget': 814,
#  'street': 814,
#  'scari': 812,
#  'british': 811,
#  'crime': 807,
#  'fire': 807,
#  'water': 806,
#  'battl': 806,
#  'narrat': 805,
#  'drive': 804,
#  'sing': 802,
#  'realist': 802,
#  'class': 800,
#  'win': 799,
#  'intellig': 798,
#  'posit': 797,
#  'charm': 797,
#  'agre': 795,
#  'peter': 793,
#  'accept': 793,
#  'mark': 792,
#  'crew': 791,
#  'earth': 790,
#  'romant': 790,
#  'except': 789,
#  'chase': 787,
#  'weak': 787,
#  'bunch': 786,
#  'german': 785,
#  'atmospher': 784,
#  'marri': 783,
#  'season': 781,
#  'admit': 779,
#  'suck': 778,
#  'filmbr': 776,
#  'dull': 776,
#  'box': 776,
#  'spoiler': 774,
#  'storylin': 773,
#  'whi': 772,
#  'vampir': 772,
#  'odd': 771,
#  'exist': 771,
#  'need': 771,
#  'island': 770,
#  'aspect': 770,
#  'attack': 769,
#  'middl': 769,
#  'issu': 767,
#  'artist': 767,
#  'suggest': 767,
#  'date': 765,
#  'larg': 765,
#  'student': 764,
#  'bother': 759,
#  'easi': 757,
#  'greatest': 757,
#  'throw': 756,
#  'best': 755,
#  'easili': 754,
#  'fantast': 753,
#  'eventu': 753,
#  'materi': 753,
#  'back': 752,
#  'stage': 751,
#  'reveal': 751,
#  'refer': 751,
#  'truth': 750,
#  'victim': 748,
#  'futur': 745,
#  'king': 744,
#  'bill': 741,
#  'about': 738,
#  'cartoon': 736,
#  'gay': 736,
#  'parti': 735,
#  'adapt': 734,
#  'deep': 733,
#  'shame': 732,
#  'befor': 731,
#  'period': 731,
#  'inspir': 728,
#  'over': 726,
#  'brought': 724,
#  'togeth': 722,
#  'standard': 722,
#  'secret': 721,
#  'express': 720,
#  'th': 719,
#  'prison': 718,
#  'lie': 717,
#  'famous': 716,
#  'adult': 716,
#  'masterpiec': 716,
#  'troubl': 715,
#  'premis': 715,
#  'straight': 714,
#  'cri': 714,
#  'overal': 711,
#  'us': 709,
#  'oh': 709,
#  'memor': 708,
#  'utter': 708,
#  'clever': 707,
#  'busi': 707,
#  'exampl': 706,
#  'lose': 705,
#  'scifi': 704,
#  'attract': 704,
#  'let': 703,
#  'cultur': 702,
#  'richard': 700,
#  'zombi': 699,
#  'color': 699,
#  'suffer': 697,
#  'week': 695,
#  'finish': 694,
#  'pure': 692,
#  'america': 691,
#  'list': 690,
#  'depict': 690,
#  'ultim': 689,
#  'did': 689,
#  'romanc': 687,
#  'slight': 687,
#  'mad': 687,
#  'ask': 687,
#  'imdb': 685,
#  'background': 684,
#  'mess': 684,
#  'serious': 683,
#  'male': 682,
#  'rare': 679,
#  'ever': 679,
#  'match': 679,
#  'hot': 679,
#  'cheesi': 678,
#  'societi': 677,
#  'frank': 676,
#  'wood': 676,
#  'later': 675,
#  'mix': 675,
#  'sudden': 675,
#  'footag': 674,
#  'wit': 673,
#  'constant': 669,
#  'tom': 668,
#  'stereotyp': 667,
#  'rich': 666,
#  'studio': 664,
#  'oscar': 664,
#  'averag': 662,
#  'enough': 662,
#  'wear': 662,
#  'adventur': 659,
#  'difficult': 658,
#  'choic': 658,
#  'dramat': 655,
#  'second': 655,
#  'land': 653,
#  'project': 650,
#  'treat': 650,
#  'leaf': 649,
#  'warn': 648,
#  'children': 647,
#  'steal': 645,
#  'spent': 644,
#  'uniqu': 644,
#  'fast': 643,
#  'flaw': 643,
#  'fear': 643,
#  'public': 642,
#  'away': 642,
#  'ok': 641,
#  'ride': 641,
#  'amount': 640,
#  'accent': 640,
#  'grow': 640,
#  'valu': 640,
#  'weird': 638,
#  'lame': 638,
#  'fli': 637,
#  'compani': 637,
#  'control': 637,
#  'down': 636,
#  'remak': 636,
#  'amus': 634,
#  'teen': 633,
#  'track': 631,
#  'connect': 630,
#  'travel': 629,
#  'even': 628,
#  'front': 626,
#  'dumb': 626,
#  'la': 625,
#  'appeal': 625,
#  'red': 625,
#  'scare': 624,
#  'surviv': 622,
#  'dont': 621,
#  'costum': 618,
#  'inform': 617,
#  'promis': 617,
#  'superb': 616,
#  'girlfriend': 616,
#  'bare': 616,
#  'brain': 615,
#  'at': 615,
#  'struggl': 614,
#  'plain': 614,
#  'moral': 613,
#  'my': 613,
#  'italian': 613,
#  'fiction': 613,
#  'go': 612,
#  'memori': 611,
#  'channel': 609,
#  'babi': 609,
#  'crazi': 608,
#  'histor': 606,
#  'park': 606,
#  'stick': 604,
#  'plenti': 604,
#  'blue': 602,
#  'term': 601,
#  'york': 600,
#  'screenplay': 599,
#  'im': 597,
#  'free': 594,
#  'creatur': 594,
#  'innoc': 592,
#  'done': 591,
#  'design': 591,
#  'lover': 591,
#  'record': 591,
#  'popular': 591,
#  'said': 590,
#  'someth': 588,
#  'answer': 588,
#  'are': 587,
#  'store': 587,
#  'listen': 585,
#  'scream': 585,
#  'disturb': 584,
#  'potenti': 584,
#  'creepi': 582,
#  'els': 582,
#  'univers': 582,
#  'beat': 581,
#  'gang': 581,
#  'repeat': 581,
#  'eat': 579,
#  'caught': 578,
#  'award': 578,
#  'combin': 578,
#  'spirit': 576,
#  'paul': 575,
#  'van': 575,
#  'earlier': 573,
#  'destroy': 573,
#  'judg': 572,
#  'concept': 572,
#  'either': 571,
#  'execut': 571,
#  'de': 571,
#  'equal': 570,
#  'purpos': 569,
#  'older': 567,
#  'danger': 566,
#  'dress': 566,
#  'abil': 566,
#  'catch': 564,
#  'collect': 562,
#  'band': 562,
#  'instead': 562,
#  'indian': 561,
#  'generat': 561,
#  'hole': 561,
#  'ship': 560,
#  'search': 560,
#  'soul': 559,
#  'respons': 558,
#  'familiar': 557,
#  'magic': 557,
#  'arriv': 556,
#  'cute': 555,
#  'tast': 555,
#  'camp': 555,
#  'bond': 555,
#  'intens': 554,
#  'joe': 554,
#  'race': 554,
#  'tortur': 553,
#  'jump': 551,
#  'kick': 550,
#  'japanes': 550,
#  'engag': 548,
#  'realli': 547,
#  'drag': 545,
#  'roll': 544,
#  'centuri': 544,
#  'prove': 544,
#  'fake': 543,
#  'hair': 542,
#  'ann': 542,
#  'himself': 541,
#  'introduc': 540,
#  'meant': 540,
#  'sick': 538,
#  'share': 538,
#  'common': 537,
#  'languag': 535,
#  'door': 534,
#  'pathet': 532,
#  'liter': 532,
#  'depth': 531,
#  'extra': 530,
#  'lee': 529,
#  'hitchcock': 529,
#  'player': 527,
#  'genuin': 527,
#  'intent': 526,
#  'commit': 525,
#  'fantasi': 525,
#  'wild': 525,
#  'consid': 525,
#  'reach': 524,
#  'harri': 524,
#  'limit': 520,
#  'colleg': 520,
#  'pop': 520,
#  'aliv': 519,
#  'bed': 519,
#  'intrigu': 517,
#  'pleas': 517,
#  'era': 517,
#  'yet': 516,
#  'cat': 516,
#  'violent': 515,
#  'tension': 515,
#  'own': 515,
#  'complex': 514,
#  'interview': 513,
#  'anoth': 512,
#  'mistak': 512,
#  'fascin': 512,
#  'social': 512,
#  'itself': 511,
#  'from': 510,
#  'yeah': 510,
#  'younger': 509,
#  'charl': 509,
#  'achiev': 509,
#  'fair': 507,
#  'maker': 507,
#  'nation': 507,
#  'while': 506,
#  'spot': 505,
#  'seem': 504,
#  'ago': 504,
#  'consist': 503,
#  'allow': 502,
#  'road': 501,
#  'bizarr': 501,
#  'cold': 501,
#  'when': 501,
#  'women': 501,
#  'approach': 500,
#  'million': 500,
#  'describ': 500,
#  'humour': 499,
#  'receiv': 499,
#  'physic': 499,
#  'minor': 499,
#  'sweet': 499,
#  'stun': 497,
#  'longer': 496,
#  'biggest': 495,
#  'angel': 495,
#  'claim': 495,
#  'demon': 495,
#  'wrote': 494,
#  'intend': 494,
#  'embarrass': 494,
#  'ruin': 493,
#  'mood': 493,
#  'skill': 492,
#  'scienc': 492,
#  'pointless': 492,
#  'hurt': 492,
#  'passion': 492,
#  'flat': 491,
#  'genius': 491,
#  'agent': 491,
#  'idiot': 490,
#  'still': 490,
#  'disney': 490,
#  'although': 490,
#  'okay': 489,
#  'laughabl': 488,
#  'normal': 488,
#  'pass': 488,
#  'giant': 487,
#  'step': 487,
#  'ray': 487,
#  'imposs': 486,
#  'sleep': 486,
#  'nuditi': 486,
#  'ghost': 485,
#  'scientist': 485,
#  'drop': 484,
#  'provid': 483,
#  'count': 483,
#  'russian': 482,
#  'tire': 482,
#  'unbeliev': 481,
#  'ed': 481,
#  'scott': 480,
#  'awesom': 479,
#  'journey': 478,
#  'delight': 478,
#  'belief': 478,
#  'trash': 477,
#  'blow': 476,
#  'desper': 475,
#  'through': 475,
#  'plane': 475,
#  'cost': 474,
#  'suit': 474,
#  'glad': 472,
#  'manner': 471,
#  'trip': 471,
#  'enter': 471,
#  'mental': 468,
#  'suspect': 468,
#  'garbag': 468,
#  'govern': 466,
#  'creativ': 464,
#  'armi': 464,
#  'arm': 464,
#  'solid': 461,
#  'handl': 460,
#  'rais': 460,
#  'tone': 460,
#  'gag': 459,
#  'cinemat': 459,
#  'bought': 459,
#  'affair': 459,
#  'haunt': 459,
#  'cross': 458,
#  'edg': 458,
#  'burn': 457,
#  'rule': 455,
#  ...}

# %%
ids = dict((word, i) for i,word in enumerate(frequency))

# %%
word_from_id = {v: k for k, v in ids.items()}

# %% [markdown]
# # Back Of Words:

# %%
number_of_words = len(ids)
number_of_docs = texts.shape[0]
backOfWords = lil_matrix((number_of_docs, number_of_words), dtype=float)

# %%
for i, row in tqdm(texts.iterrows()):
    for word in row[column_name]:
        if word in ids:
            backOfWords[i ,ids[word]] += 1
# Out:
# 25000it [00:32, 773.24it/s]

# %%
doc_word_counts = {word: 0 for word in bag_of_words}
for i, row in tqdm(texts.iterrows()):
    for word in set(row[column_name]):
        doc_word_counts[word] += 1
# Out:
# 25000it [00:03, 7524.72it/s]

# %% [markdown]
# #### Number of docs that the given word appears in:

# %%
dict(filter(lambda x : len(x[0]) > 1, sorted(doc_word_counts.items(), key=lambda x: x[1], reverse=True)))
# Out:
# {'movi': 15933,
#  'film': 14623,
#  'br': 14537,
#  'time': 9684,
#  'good': 9209,
#  'watch': 9006,
#  'it': 8812,
#  'charact': 8102,
#  'the': 7742,
#  'stori': 7443,
#  'act': 6599,
#  'scene': 6486,
#  'great': 6349,
#  'peopl': 6046,
#  'bad': 6022,
#  'love': 5784,
#  'play': 5648,
#  'show': 5332,
#  'plot': 4986,
#  'actor': 4929,
#  'work': 4822,
#  'life': 4666,
#  'this': 4523,
#  'year': 4522,
#  'find': 4196,
#  'part': 3883,
#  'lot': 3864,
#  'man': 3803,
#  'feel': 3801,
#  'perform': 3766,
#  'interest': 3764,
#  'give': 3576,
#  'real': 3530,
#  'director': 3501,
#  'enjoy': 3370,
#  'cast': 3345,
#  'end': 3332,
#  'guy': 3202,
#  'start': 3163,
#  'funni': 3115,
#  'thought': 3100,
#  'turn': 3049,
#  'well': 3033,
#  'point': 2997,
#  'role': 2991,
#  'set': 2979,
#  'direct': 2978,
#  'fact': 2933,
#  'one': 2911,
#  'day': 2895,
#  'star': 2888,
#  'and': 2871,
#  'music': 2836,
#  'minut': 2836,
#  'pretti': 2819,
#  'all': 2769,
#  'effect': 2760,
#  'long': 2743,
#  'that': 2713,
#  'big': 2713,
#  'world': 2675,
#  'put': 2666,
#  'line': 2662,
#  'bit': 2652,
#  'friend': 2649,
#  'fan': 2643,
#  'person': 2628,
#  'woman': 2563,
#  'high': 2561,
#  'complet': 2553,
#  'young': 2546,
#  'final': 2536,
#  'script': 2535,
#  'live': 2533,
#  'origin': 2514,
#  'kill': 2477,
#  'reason': 2474,
#  'girl': 2462,
#  'kind': 2448,
#  'laugh': 2439,
#  'expect': 2435,
#  'comedi': 2411,
#  'beauti': 2383,
#  'call': 2382,
#  'is': 2324,
#  'make': 2308,
#  'action': 2304,
#  'place': 2303,
#  'in': 2281,
#  'recommend': 2251,
#  'me': 2246,
#  'way': 2226,
#  'lead': 2225,
#  'entertain': 2219,
#  'there': 2199,
#  'shot': 2197,
#  'howev': 2180,
#  'worth': 2173,
#  'happen': 2165,
#  'moment': 2156,
#  'screen': 2154,
#  'worst': 2139,
#  'wonder': 2126,
#  'idea': 2104,
#  'hard': 2098,
#  'tv': 2096,
#  'surpris': 2090,
#  'fun': 2089,
#  'run': 2081,
#  'read': 2074,
#  'horror': 2067,
#  'poor': 2054,
#  'bore': 2036,
#  'hope': 2033,
#  'move': 2023,
#  'kid': 2019,
#  'main': 1995,
#  'take': 1984,
#  'audienc': 1978,
#  'famili': 1965,
#  'them': 1949,
#  'dvd': 1945,
#  'sens': 1937,
#  'job': 1913,
#  'begin': 1886,
#  'perfect': 1861,
#  'wast': 1860,
#  'special': 1859,
#  'excel': 1843,
#  'true': 1843,
#  'sound': 1842,
#  'suppos': 1827,
#  'open': 1826,
#  'understand': 1803,
#  'problem': 1802,
#  'think': 1799,
#  'here': 1797,
#  'seri': 1789,
#  'view': 1789,
#  'product': 1788,
#  'mind': 1785,
#  'him': 1785,
#  'total': 1771,
#  'classic': 1770,
#  'nice': 1769,
#  'you': 1768,
#  'left': 1753,
#  'american': 1752,
#  'care': 1751,
#  'face': 1751,
#  'out': 1740,
#  'money': 1740,
#  'again': 1737,
#  'on': 1725,
#  'short': 1721,
#  'hour': 1715,
#  'night': 1711,
#  'but': 1710,
#  'involv': 1693,
#  'write': 1685,
#  'piec': 1670,
#  'includ': 1667,
#  'absolut': 1665,
#  'talk': 1662,
#  'fall': 1645,
#  'review': 1641,
#  'head': 1634,
#  'want': 1630,
#  'appear': 1616,
#  'rememb': 1615,
#  'attempt': 1613,
#  'rate': 1612,
#  'coupl': 1605,
#  'simpli': 1601,
#  'disappoint': 1601,
#  'word': 1595,
#  'hand': 1588,
#  'human': 1586,
#  'so': 1574,
#  'lack': 1573,
#  'death': 1562,
#  'boy': 1556,
#  'eye': 1555,
#  'rest': 1555,
#  'viewer': 1552,
#  'terribl': 1531,
#  'decid': 1531,
#  'wrong': 1528,
#  'black': 1524,
#  'save': 1523,
#  'stupid': 1517,
#  'mean': 1511,
#  'featur': 1511,
#  'home': 1508,
#  'releas': 1507,
#  'portray': 1505,
#  'produc': 1494,
#  'talent': 1489,
#  'dead': 1487,
#  'john': 1486,
#  'titl': 1476,
#  'book': 1475,
#  'top': 1474,
#  'pictur': 1452,
#  'look': 1448,
#  'full': 1447,
#  'not': 1421,
#  'bring': 1421,
#  'camera': 1420,
#  'version': 1415,
#  'child': 1412,
#  'war': 1410,
#  'case': 1408,
#  'hollywood': 1408,
#  'power': 1406,
#  'sort': 1400,
#  'like': 1400,
#  'guess': 1399,
#  'base': 1397,
#  'amaz': 1395,
#  'aw': 1389,
#  'see': 1388,
#  'emot': 1387,
#  'die': 1384,
#  'chang': 1375,
#  'wife': 1372,
#  'up': 1369,
#  'men': 1369,
#  'budget': 1368,
#  'comment': 1363,
#  'dialogu': 1360,
#  'leav': 1358,
#  'as': 1333,
#  'sad': 1332,
#  'humor': 1330,
#  'earli': 1323,
#  'creat': 1322,
#  'hous': 1314,
#  'close': 1311,
#  'fight': 1311,
#  'experi': 1309,
#  'mention': 1309,
#  'school': 1306,
#  'matter': 1304,
#  'flick': 1304,
#  'meet': 1303,
#  'name': 1302,
#  'if': 1300,
#  'manag': 1300,
#  'video': 1297,
#  'qualiti': 1295,
#  'thing': 1291,
#  'small': 1291,
#  'entir': 1289,
#  'murder': 1281,
#  'too': 1279,
#  'now': 1278,
#  'style': 1277,
#  'tell': 1273,
#  'stop': 1270,
#  'forc': 1269,
#  'written': 1269,
#  'extrem': 1269,
#  'horribl': 1252,
#  'wors': 1252,
#  'dark': 1241,
#  'other': 1240,
#  'episod': 1233,
#  'imagin': 1231,
#  'impress': 1215,
#  'come': 1206,
#  'light': 1205,
#  'seen': 1204,
#  'side': 1203,
#  'basic': 1202,
#  'what': 1202,
#  'sequenc': 1201,
#  'father': 1200,
#  'drama': 1197,
#  'lost': 1194,
#  'brilliant': 1188,
#  'favorit': 1185,
#  'fail': 1180,
#  'song': 1179,
#  'develop': 1177,
#  'believ': 1177,
#  'her': 1171,
#  'joke': 1171,
#  'sex': 1169,
#  'deal': 1165,
#  'mother': 1165,
#  'felt': 1164,
#  'know': 1161,
#  'wait': 1161,
#  'writer': 1160,
#  'present': 1158,
#  'miss': 1158,
#  'learn': 1154,
#  'actress': 1152,
#  'sit': 1137,
#  'cut': 1137,
#  'age': 1135,
#  'hit': 1134,
#  'stand': 1132,
#  'type': 1129,
#  'heart': 1129,
#  'say': 1120,
#  'add': 1119,
#  'rent': 1119,
#  'cinema': 1117,
#  'be': 1115,
#  'deserv': 1111,
#  'gave': 1111,
#  'credit': 1109,
#  'group': 1098,
#  'support': 1097,
#  'fine': 1096,
#  'walk': 1088,
#  'natur': 1087,
#  'art': 1084,
#  'though': 1084,
#  'hilari': 1083,
#  'possibl': 1083,
#  'stay': 1082,
#  'today': 1080,
#  'to': 1071,
#  'score': 1069,
#  'twist': 1067,
#  'question': 1067,
#  'do': 1067,
#  'hate': 1065,
#  'import': 1062,
#  'anim': 1061,
#  'strong': 1060,
#  'with': 1056,
#  'car': 1055,
#  'brother': 1054,
#  'success': 1048,
#  'order': 1040,
#  'touch': 1038,
#  'situat': 1038,
#  'for': 1034,
#  'chanc': 1033,
#  'stuff': 1032,
#  'obvious': 1029,
#  'realiz': 1027,
#  'major': 1025,
#  'late': 1022,
#  'relationship': 1019,
#  'appar': 1018,
#  'histori': 1015,
#  'genr': 1015,
#  'incred': 1013,
#  'heard': 1013,
#  'filmmak': 1005,
#  'continu': 1004,
#  'voic': 999,
#  'help': 995,
#  'general': 995,
#  'ridicul': 994,
#  'hero': 988,
#  'cours': 988,
#  'right': 986,
#  'white': 982,
#  'edit': 981,
#  'annoy': 979,
#  'theme': 975,
#  'speak': 971,
#  'robert': 969,
#  'pick': 963,
#  'evil': 962,
#  'yes': 959,
#  'level': 958,
#  'hold': 956,
#  'itbr': 956,
#  'decent': 956,
#  'huge': 953,
#  'return': 951,
#  'compar': 950,
#  'bodi': 944,
#  'son': 944,
#  'actual': 941,
#  'figur': 940,
#  'number': 939,
#  'told': 937,
#  'event': 937,
#  'pace': 932,
#  'deliv': 929,
#  'also': 929,
#  'was': 923,
#  'god': 921,
#  'similar': 921,
#  'opinion': 921,
#  'mysteri': 918,
#  'better': 918,
#  'effort': 915,
#  'predict': 912,
#  'simpl': 909,
#  'result': 905,
#  'element': 904,
#  'strang': 901,
#  'daughter': 900,
#  'convinc': 899,
#  'shown': 894,
#  'anyway': 892,
#  'michael': 891,
#  'cool': 890,
#  'citi': 887,
#  'slow': 885,
#  'cinematographi': 883,
#  'town': 883,
#  'buy': 882,
#  'countri': 882,
#  'critic': 880,
#  'career': 875,
#  'offer': 873,
#  'suspens': 873,
#  'subject': 873,
#  'no': 872,
#  'hell': 871,
#  'sure': 869,
#  'state': 869,
#  'off': 868,
#  'game': 868,
#  'local': 867,
#  'check': 866,
#  'made': 866,
#  'pain': 863,
#  'more': 862,
#  'shoot': 862,
#  'quick': 860,
#  'explain': 859,
#  'which': 857,
#  'first': 857,
#  'honest': 856,
#  'usual': 855,
#  'hear': 854,
#  'note': 853,
#  'femal': 853,
#  'happi': 852,
#  'pull': 852,
#  'avoid': 850,
#  'then': 849,
#  'of': 846,
#  'confus': 845,
#  'silli': 842,
#  'unfortun': 839,
#  'shock': 839,
#  'dialog': 838,
#  'break': 837,
#  'clear': 837,
#  'visual': 834,
#  'attent': 833,
#  'killer': 832,
#  'realiti': 831,
#  'blood': 827,
#  'knew': 822,
#  'remain': 817,
#  'comic': 817,
#  'crap': 814,
#  'who': 813,
#  'doubt': 809,
#  'fit': 808,
#  'etc': 805,
#  'relat': 805,
#  'remind': 804,
#  'detail': 804,
#  'differ': 803,
#  'theater': 803,
#  'pay': 800,
#  'room': 800,
#  'typic': 800,
#  'soundtrack': 797,
#  'escap': 797,
#  'due': 797,
#  'much': 795,
#  'david': 793,
#  'cheap': 789,
#  'moviebr': 789,
#  'focus': 787,
#  'violenc': 785,
#  'excit': 784,
#  'mr': 781,
#  'spend': 780,
#  'carri': 779,
#  'respect': 779,
#  'singl': 776,
#  'or': 775,
#  'cover': 774,
#  'discov': 771,
#  'fill': 769,
#  'form': 768,
#  'danc': 767,
#  'offic': 764,
#  'previous': 763,
#  'ad': 760,
#  'build': 759,
#  'follow': 758,
#  'locat': 758,
#  'notic': 757,
#  'ten': 754,
#  'except': 754,
#  'forget': 754,
#  'english': 751,
#  'member': 750,
#  'polic': 746,
#  'imag': 745,
#  'posit': 743,
#  'agre': 743,
#  'captur': 743,
#  'admit': 741,
#  'modern': 740,
#  'clich': 734,
#  'messag': 733,
#  'sequel': 729,
#  'husband': 727,
#  'plan': 727,
#  'best': 724,
#  'parent': 721,
#  'jame': 720,
#  'sister': 719,
#  'ladi': 719,
#  'copi': 719,
#  'tale': 718,
#  'filmbr': 717,
#  'team': 714,
#  'realist': 713,
#  'intellig': 712,
#  'bunch': 712,
#  'televis': 712,
#  'back': 711,
#  'weak': 711,
#  'atmospher': 708,
#  'polit': 707,
#  'charm': 707,
#  'odd': 705,
#  'easi': 705,
#  'middl': 705,
#  'teenag': 705,
#  'need': 704,
#  'bother': 703,
#  'aspect': 702,
#  'larg': 701,
#  'suggest': 700,
#  'easili': 699,
#  'gore': 696,
#  'about': 695,
#  'over': 695,
#  'whi': 694,
#  'overal': 693,
#  'befor': 691,
#  'storylin': 691,
#  'monster': 691,
#  'sexual': 689,
#  'thriller': 689,
#  'exist': 687,
#  'dull': 684,
#  'materi': 682,
#  'throw': 681,
#  'dream': 680,
#  'scari': 679,
#  'cop': 679,
#  'accept': 678,
#  'drive': 676,
#  'class': 674,
#  'futur': 673,
#  'dog': 673,
#  'refer': 673,
#  'win': 673,
#  'brought': 672,
#  'spoiler': 669,
#  'gun': 668,
#  'fantast': 668,
#  'documentari': 668,
#  'shame': 668,
#  'togeth': 668,
#  'street': 667,
#  'eventu': 665,
#  'issu': 664,
#  'air': 664,
#  'date': 662,
#  'narrat': 662,
#  'exampl': 662,
#  'reveal': 660,
#  'troubl': 660,
#  'inspir': 659,
#  'let': 658,
#  'train': 658,
#  'mark': 656,
#  'marri': 656,
#  'did': 655,
#  'william': 655,
#  'memor': 655,
#  'standard': 655,
#  'box': 651,
#  'straight': 651,
#  'finish': 650,
#  'period': 649,
#  'masterpiec': 648,
#  'villain': 648,
#  'truth': 648,
#  'lose': 647,
#  'drug': 646,
#  'utter': 646,
#  'stage': 645,
#  'master': 645,
#  'premis': 645,
#  'oh': 644,
#  'slight': 642,
#  'background': 641,
#  'pure': 641,
#  'deep': 641,
#  'suffer': 641,
#  'list': 641,
#  'later': 641,
#  'greatest': 641,
#  'attract': 641,
#  'rare': 640,
#  'clever': 639,
#  'serious': 639,
#  'express': 638,
#  'mess': 636,
#  'ultim': 635,
#  'famous': 635,
#  'chase': 635,
#  'ever': 634,
#  'enough': 633,
#  'romant': 633,
#  'suck': 631,
#  'crime': 630,
#  'mix': 630,
#  'georg': 628,
#  'artist': 626,
#  'attack': 625,
#  'cri': 625,
#  'fire': 624,
#  'peter': 623,
#  'difficult': 623,
#  'ask': 622,
#  'space': 618,
#  'busi': 618,
#  'second': 617,
#  'secret': 616,
#  'sudden': 616,
#  'british': 615,
#  'us': 614,
#  'french': 614,
#  'imdb': 613,
#  'wit': 613,
#  'sing': 612,
#  'water': 611,
#  'leaf': 611,
#  'constant': 611,
#  'away': 607,
#  'week': 606,
#  'victim': 606,
#  'th': 604,
#  'rock': 604,
#  'cheesi': 604,
#  'fast': 602,
#  'earth': 602,
#  'spent': 601,
#  'dramat': 601,
#  'crew': 601,
#  'even': 601,
#  'averag': 600,
#  'down': 600,
#  'treat': 599,
#  'amount': 599,
#  'adult': 599,
#  'at': 597,
#  'lie': 596,
#  'valu': 595,
#  'student': 595,
#  'warn': 594,
#  'grow': 594,
#  'adapt': 594,
#  'ok': 593,
#  'depict': 593,
#  'wear': 592,
#  'choic': 591,
#  'uniqu': 590,
#  'go': 588,
#  'battl': 588,
#  'steal': 586,
#  'front': 584,
#  'male': 582,
#  'amus': 577,
#  'romanc': 577,
#  'western': 577,
#  'parti': 577,
#  'color': 577,
#  'flaw': 575,
#  'bare': 575,
#  'appeal': 573,
#  'said': 573,
#  'my': 572,
#  'stick': 570,
#  'rich': 569,
#  'public': 568,
#  'frank': 568,
#  'doctor': 568,
#  'fear': 567,
#  'superb': 566,
#  'done': 565,
#  'plain': 565,
#  'bill': 564,
#  'america': 564,
#  'richard': 563,
#  'jack': 563,
#  'someth': 563,
#  'societi': 561,
#  'weird': 561,
#  'oscar': 561,
#  'dont': 560,
#  'connect': 560,
#  'hot': 560,
#  'project': 559,
#  'lame': 559,
#  'stereotyp': 559,
#  'els': 559,
#  'promis': 559,
#  'are': 558,
#  'cultur': 558,
#  'studio': 556,
#  'caught': 556,
#  'struggl': 555,
#  'costum': 553,
#  'plenti': 553,
#  'track': 553,
#  'adventur': 550,
#  'land': 549,
#  'surviv': 548,
#  'either': 546,
#  'im': 546,
#  'free': 543,
#  'term': 543,
#  'equal': 543,
#  'screenplay': 542,
#  'combin': 542,
#  'potenti': 542,
#  'memori': 542,
#  'earlier': 541,
#  'control': 541,
#  'ride': 541,
#  'design': 539,
#  'instead': 539,
#  'repeat': 538,
#  'compani': 535,
#  'inform': 535,
#  'scare': 534,
#  'catch': 534,
#  'innoc': 533,
#  'mad': 532,
#  'girlfriend': 531,
#  'purpos': 528,
#  'accent': 528,
#  'scifi': 526,
#  'beat': 525,
#  'children': 523,
#  'listen': 522,
#  'execut': 522,
#  'abil': 522,
#  'dumb': 521,
#  'fli': 520,
#  'channel': 520,
#  'store': 519,
#  'crazi': 518,
#  'collect': 516,
#  'familiar': 516,
#  'answer': 516,
#  'concept': 516,
#  'himself': 514,
#  'respons': 513,
#  'danger': 512,
#  'brain': 511,
#  'disturb': 511,
#  'prove': 511,
#  'travel': 511,
#  'older': 510,
#  'search': 510,
#  'alien': 509,
#  'jump': 508,
#  'share': 508,
#  'popular': 508,
#  'lover': 507,
#  'teen': 505,
#  'tast': 505,
#  'record': 505,
#  'intens': 504,
#  'fiction': 504,
#  'destroy': 504,
#  'consid': 504,
#  'scream': 503,
#  'genuin': 503,
#  'spirit': 503,
#  'liter': 503,
#  'roll': 502,
#  'engag': 502,
#  'common': 501,
#  'moral': 501,
#  'award': 499,
#  'generat': 497,
#  'cute': 496,
#  'arriv': 496,
#  'kick': 496,
#  'dress': 496,
#  'hole': 496,
#  'realli': 496,
#  'pathet': 495,
#  'king': 495,
#  'own': 495,
#  'soldier': 495,
#  'footag': 494,
#  'depth': 494,
#  'red': 493,
#  'itself': 492,
#  'dr': 492,
#  'introduc': 492,
#  'meant': 492,
#  'from': 491,
#  'eat': 490,
#  'drag': 490,
#  'ago': 489,
#  'yet': 488,
#  'season': 487,
#  'while': 485,
#  'anoth': 485,
#  'pleas': 485,
#  'reach': 485,
#  'fair': 484,
#  'island': 483,
#  'intrigu': 482,
#  'histor': 482,
#  'york': 482,
#  'centuri': 479,
#  'fascin': 478,
#  'extra': 478,
#  'remak': 477,
#  'la': 477,
#  'limit': 474,
#  'seem': 474,
#  'creepi': 474,
#  'intent': 474,
#  'magic': 473,
#  'although': 473,
#  'allow': 472,
#  'languag': 471,
#  'when': 471,
#  'tom': 470,
#  'describ': 470,
#  'violent': 469,
#  'through': 469,
#  'tension': 468,
#  'spot': 468,
#  'stun': 468,
#  'still': 467,
#  'sweet': 467,
#  'approach': 466,
#  'pass': 466,
#  'aliv': 465,
#  'mistak': 465,
#  'longer': 464,
#  'era': 464,
#  'complex': 464,
#  'achiev': 464,
#  'laughabl': 462,
#  'door': 462,
#  'wrote': 462,
#  'univers': 462,
#  'imposs': 460,
#  'hair': 460,
#  'minor': 460,
#  'judg': 459,
#  'younger': 458,
#  'paul': 458,
#  'receiv': 458,
#  'blue': 457,
#  'biggest': 457,
#  'glad': 456,
#  'mood': 456,
#  'consist': 456,
#  'intend': 456,
#  'soul': 456,
#  'player': 455,
#  'wood': 455,
#  'fake': 455,
#  'unbeliev': 453,
#  'physic': 453,
#  'yeah': 453,
#  'pop': 453,
#  'provid': 452,
#  'desper': 452,
#  'tire': 452,
#  'maker': 452,
#  'babi': 452,
#  'embarrass': 452,
#  'german': 450,
#  'skill': 448,
#  'social': 448,
#  'commit': 447,
#  'idiot': 447,
#  'flat': 445,
#  'ruin': 445,
#  'manner': 444,
#  'bizarr': 444,
#  'claim': 443,
#  'drop': 441,
#  'million': 441,
#  'genius': 440,
#  'delight': 440,
#  'nuditi': 439,
#  'okay': 439,
#  'normal': 438,
#  'sick': 438,
#  'pointless': 437,
#  'bought': 436,
#  'women': 435,
#  'blow': 434,
#  'cold': 434,
#  'creatur': 433,
#  'fantasi': 432,
#  'trash': 432,
#  'anyth': 432,
#  'handl': 431,
#  'solid': 430,
#  'sleep': 430,
#  'cost': 430,
#  'belief': 430,
#  'loos': 430,
#  'prison': 429,
#  'suspect': 429,
#  'cinemat': 428,
#  'awesom': 428,
#  'match': 427,
#  'conclus': 426,
#  'tone': 426,
#  'suit': 426,
#  'immedi': 425,
#  'gay': 424,
#  'trip': 423,
#  'creativ': 423,
#  'wild': 423,
#  'nation': 423,
#  'humour': 422,
#  'park': 422,
#  'some': 421,
#  'occasion': 421,
#  'enter': 421,
#  'remark': 420,
#  'step': 419,
#  'tortur': 419,
#  'de': 419,
#  'rais': 418,
#  'road': 418,
#  'everyon': 418,
#  'mental': 418,
#  'cartoon': 418,
#  'garbag': 417,
#  'excus': 416,
#  'folk': 416,
#  'last': 415,
#  'addit': 415,
#  'studi': 413,
#  'he': 413,
#  'concern': 413,
#  'sceneri': 412,
#  'around': 412,
#  'area': 411,
#  'passion': 411,
#  'photographi': 410,
#  'camp': 410,
#  'italian': 410,
#  'display': 409,
#  'colleg': 409,
#  'presenc': 409,
#  'smart': 409,
#  'hurt': 409,
#  'tear': 407,
#  'race': 407,
#  'ignor': 407,
#  'visit': 407,
#  'compel': 405,
#  'get': 404,
#  'fashion': 403,
#  'bottom': 403,
#  'sign': 403,
#  'edg': 402,
#  'decad': 402,
#  'haunt': 402,
#  'subtl': 401,
#  'old': 401,
#  'serv': 399,
#  'affect': 398,
#  'cross': 398,
#  'rip': 398,
#  'caus': 398,
#  'thrown': 398,
#  'chemistri': 398,
#  'gem': 398,
#  ...}

# %% [markdown]
# # 5. IDF

# %%
# Sparse Matrix for each - the fastest way
def for_each(function, x):
    cx = x.tocoo()    
    for i,j,v in tqdm(zip(cx.row, cx.col, cx.data)):
        function((i,j,v))

# %%
def mapAsIDF(x):
    backOfWords[x[0],x[1]] = x[2] * log(float(number_of_docs)/doc_word_counts[word_from_id[x[1]]])
    
for_each(mapAsIDF , backOfWords)
# Out:
# 2000629it [00:26, 74482.15it/s]

# %% [markdown]
# # 6. Search

# %%
def convert_to_vector(query):
    query = set(map(lambda x : ps.stem(re.sub('[^a-z]+', '', ps.stem(x.lower()))), query.split()))
    vec = lil_matrix((1,number_of_words), dtype=float)
    for word in query:
        if ids.get(word) is not None:
            vec[0, ids[word]] += 1
    return vec

# %%
def get_best_result(query):
    query_vec = convert_to_vector(query)
    query_length = query_vec.count_nonzero()
    matches = {i: 0 for i in range(number_of_docs)}
    for i in tqdm(range(number_of_docs)):
        matches[i] = query_vec.multiply(backOfWords[i]).sum()/(query_length * backOfWords[i].count_nonzero())
#         matches[i] = [word * backOfWords[i,j] for j,word in enumerate(query_vec.nonzero()[1])][0].sum()/(query_length * backOfWords[i].count_nonzero())
    return dict(sorted(matches.items(), key=lambda x: x[1], reverse=True))

# %%
a = pd.read_csv(filename, header=0, delimiter="\t")
a.get_value(2, column_name)
# Out:
# 'All in all, this is a movie for kids. We saw it tonight and my child loved it. At one point my kid\'s excitement was so great that sitting was impossible. However, I am a great fan of A.A. Milne\'s books which are very subtle and hide a wry intelligence behind the childlike quality of its leading characters. This film was not subtle. It seems a shame that Disney cannot see the benefit of making movies from more of the stories contained in those pages, although perhaps, it doesn\'t have the permission to use them. I found myself wishing the theater was replaying \\Winnie-the-Pooh and Tigger too\\", instead. The characters voices were very good. I was only really bothered by Kanga. The music, however, was twice as loud in parts than the dialog, and incongruous to the film.<br /><br />As for the story, it was a bit preachy and militant in tone. Overall, I was disappointed, but I would go again just to see the same excitement on my child\'s face.<br /><br />I liked Lumpy\'s laugh...."'

# %%
query = "movie for kids best for child"
query_vec = convert_to_vector(query)
best_metches = get_best_result(query)
# Out:
# 100%|██████████| 25000/25000 [00:18<00:00, 1365.43it/s]

# %%
best_metches
# Out:
# {10862: 0.1386102753107166,
#  1145: 0.13424520962586711,
#  22730: 0.12907613737952342,
#  10311: 0.10065093942150002,
#  3927: 0.098891896009910996,
#  7964: 0.09870320611171958,
#  14006: 0.097343759434908,
#  19431: 0.093516045296729328,
#  858: 0.093130152629912574,
#  21000: 0.086301762017125083,
#  12888: 0.084203198435498214,
#  23642: 0.080576320820699612,
#  4890: 0.076823979455938857,
#  10462: 0.076823979455938857,
#  4988: 0.07223726178847327,
#  10809: 0.070499828051165059,
#  20767: 0.06971595401513303,
#  22870: 0.067199970056363023,
#  4173: 0.066791100254655844,
#  20865: 0.066498328370950377,
#  22692: 0.065927930673273988,
#  24699: 0.065695051931269885,
#  2312: 0.064964495397481267,
#  9193: 0.064774082988848694,
#  23822: 0.064487958866564263,
#  21973: 0.064397085662993112,
#  22745: 0.062490416895398845,
#  21353: 0.062131641364675597,
#  8869: 0.060390563652900013,
#  18773: 0.060096631508820553,
#  11927: 0.059915323436707697,
#  6597: 0.059312604796898274,
#  15164: 0.059030661857743687,
#  848: 0.058546380135535842,
#  9345: 0.058546380135535842,
#  11636: 0.058214982707421654,
#  23993: 0.057536606002991729,
#  24385: 0.057371634966838975,
#  18377: 0.057290748446275096,
#  22047: 0.056954004584285969,
#  5858: 0.056738338645627898,
#  22181: 0.056208675268316931,
#  14540: 0.055689397714644755,
#  1046: 0.055253195283099812,
#  13177: 0.055167612768085038,
#  21437: 0.055143538148995051,
#  16352: 0.055051226966894476,
#  22780: 0.054948032269514127,
#  21641: 0.054886326045605498,
#  2140: 0.054514756426659088,
#  10327: 0.054058007371179467,
#  16910: 0.053926221075954406,
#  1412: 0.053479846368710143,
#  3265: 0.053199976294620727,
#  11144: 0.052750815032801102,
#  18132: 0.052400311840276249,
#  21845: 0.052329508118618397,
#  19373: 0.052048366321005776,
#  23709: 0.051570374988465756,
#  1311: 0.051210831794740355,
#  16083: 0.051143878162415071,
#  18184: 0.051080097978770264,
#  13700: 0.050708482541955625,
#  16800: 0.050679381910480749,
#  22088: 0.050331139670890777,
